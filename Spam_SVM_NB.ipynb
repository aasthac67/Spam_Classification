# %% [markdown]
# ## **Step 1: Reading and preparing the data**

# %%
import os
import re
import nltk
import json
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Keeping only the alphabets and storing the data in a list as tuples for both spam and ham separately

# %%
data = []

for filename in os.listdir('ham/'):
    with open(os.path.join('ham/', filename), 'rb') as f:
        s = f.read().decode("utf-8")
        news = re.sub(r'[^A-Za-z ]+', '', s)
        news = news.lower()
        data.append((news,"ham"))
        
print(len(data))
# Out:
# 3672

# %%
for filename in os.listdir('spam/'):
    with open(os.path.join('spam/', filename), 'rb') as f:
        s = f.read().decode("latin1")
        news = re.sub(r'[^A-Za-z ]+', '', s)
        news = news.lower()
        data.append((news,"spam"))
    
print(len(data))
# Out:
# 5172

# %% [markdown]
# Saving this preprocessed data in CSV format for easy access

# %%
df = pd.DataFrame(data, columns =['Email', 'Label']) 
df.to_csv('email.csv', index=False)

# %%
data = pd.read_csv("email.csv")
data.head()
# Out:
#                                                Email Label
# 0  subject re  natural gas nomination for   i wen...   ham
# 1  subject hpl nom for february    see attached f...   ham
# 2  subject re  error repairsjay for june  i need ...   ham
# 3  subject enron  hpl actuals for october   teco ...   ham
# 4  subject jan  feb midcon invoicespat dresner  a...   ham

# %%
X = data.iloc[:,0]
Y = data.iloc[:,1]

counts = data['Label'].value_counts()
print(counts)
counts.plot(kind = 'bar',color = ["green","red"])
plt.title('Bar Plot')
plt.show()
# Out:
# ham     3672
# spam    1500
# Name: Label, dtype: int64

# %% [markdown]
# ## **Step 2: Finding the unique words found in the email dataset**

# %%
def rem_stopwords(line):
    return [word for word in line.split() if word.lower() not in stopwords.words('english')]

# %%
print(X.apply(rem_stopwords))
# Out:
# 0       [subject, natural, gas, nomination, went, ahea...
# 1       [subject, hpl, nom, february, see, attached, f...
# 2       [subject, error, repairsjay, june, need, coupl...
# 3       [subject, enron, hpl, actuals, october, teco, ...
# 4       [subject, jan, feb, midcon, invoicespat, dresn...
# 5       [subject, revised, th, noms, forwarded, ami, c...
# 6       [subject, channel, dispatch, fyi, forwarded, g...
# 7       [subject, panenergy, marketing, exchange, deal...
# 8       [subject, shell, houston, openfirst, come, fir...
# 9       [subject, noms, actual, flow, thru, agree, nom...
# 10      [subject, th, noms, forwarded, ami, chokshi, c...
# 11      [subject, enron, actuals, december, teco, tap,...
# 12      [subject, meter, daren, flow, month, april, de...
# 13      [subject, mtbe, upsetsthe, mtbe, plant, determ...
# 14      [subject, meter, may, need, assistance, issue,...
# 15      [subject, meeting, thoughtsi, sitting, bit, di...
# 16      [subject, wc, revision, effective, stingray, p...
# 17      [subject, order, confirmation, footlocker, com...
# 18      [subject, ect, enron, com, email, notification...
# 19      [subject, walter, g, superior, april, nomstom,...
# 20      [subject, kcs, buy, selllauri, hpl, gas, contr...
# 21      [subject, meter, south, katy, gas, unit, alloc...
# 22      [subject, shut, meter, need, help, one, spoke,...
# 23      [subject, deletion, enrononline, user, idpassw...
# 24      [subject, x, productsplease, read, attached, m...
# 25      [subject, fw, megan, pics, original, message, ...
# 26      [subject, enron, hpl, actuals, september, mond...
# 27      [subject, september, availabilitiesthis, first...
# 28      [subject, new, production, sitara, deals, need...
# 29      [subject, activity, allocated, nomed, daren, p...
#                               ...
# 5142    [subject, archived, great, shots, california, ...
# 5143    [subject, sell, regalis, affordable, pricehi, ...
# 5144    [subject, feel, oldgo, click, help, father, pa...
# 5145    [subject, get, free, megapixel, canon, digital...
# 5146    [subject, thu, may, first, gove, rnment, mo, r...
# 5147    [subject, test, keep, ibm, laptop, product, te...
# 5148    [subject, one, suffers, painstriktuur, deliber...
# 5149    [subject, nurses, military, cops, women, unifo...
# 5150    [subject, today, orchard, guei, republic, cote...
# 5151    [subject, end, year, clearanceitem, descriptio...
# 5152    [subject, want, lose, weight, try, adipren, he...
# 5153    [subject, overseas, pharmacy, qcdo, want, inex...
# 5154    [subject, discreet, vlagra, one, needs, know, ...
# 5155    [subject, need, vicodin, need, vicodin, source...
# 5156    [subject, fwd, vl, codin, vl, gra, v, lium, xa...
# 5157    [subject, becausepaliourg, valiumxanaxcialis, ...
# 5158    [subject, ask, tina, goluuuuuuube, make, happy...
# 5159    [subject, private, videos, im, internethallo, ...
# 5160    [subject, druuugs, onliiiiine, cheaaaaphello, ...
# 5161    [subject, new, zenoil, massive, rock, sloid, e...
# 5162    [subject, impotency, embarressing, issue, buy,...
# 5163      [subject, pay, priced, pre, scription, dru, gs]
# 5164    [subject, discoveryfinally, always, worried, s...
# 5165    [subject, fwd, porn, money, make, daythe, adul...
# 5166    [subject, stop, paying, much, heal, th, sur, a...
# 5167    [subject, new, municipal, toxic, emmissions, r...
# 5168    [subject, lyz, balk, filters, forget, xof, ttb...
# 5169    [subject, microsoft, update, warning, january,...
# 5170    [subject, emerging, small, capto, exit, additi...
# 5171    [subject, buy, cheap, prescription, drugs, onl...
# Name: Email, Length: 5172, dtype: object

# %% [markdown]
# Transform words to numbers to find the unique words

# %%
num_words = CountVectorizer(analyzer = rem_stopwords).fit(X)
num_words.vocabulary_
# Out:
# {'subject': 54196,
#  'natural': 38476,
#  'gas': 23766,
#  'nomination': 39365,
#  'went': 62241,
#  'ahead': 1421,
#  'accepted': 300,
#  'nom': 39325,
#  'put': 46218,
#  'start': 53467,
#  'monthpricing': 37563,
#  'base': 5709,
#  'ticket': 57450,
#  'ignored': 28202,
#  'limit': 33646,
#  'goodprice': 24775,
#  'daren': 14940,
#  'j': 30610,
#  'farmer': 21266,
#  'pmto': 44290,
#  'lee': 33226,
#  'l': 32637,
#  'papayoti': 42328,
#  'hou': 27298,
#  'ect': 18567,
#  'ectcc': 18570,
#  'sitara': 51953,
#  'max': 35709,
#  'flex': 22197,
#  'correct': 13643,
#  'shouldthe': 51610,
#  'additional': 758,
#  'swing': 54806,
#  'included': 28710,
#  'index': 28882,
#  'forwarded': 22859,
#  'pm': 44242,
#  'michael': 36631,
#  'mitcham': 37099,
#  'enron': 19605,
#  'david': 15103,
#  'bush': 8747,
#  'ecf': 18514,
#  'mark': 35379,
#  'diedrich': 16585,
#  'gpgfin': 24894,
#  'paulfox': 42701,
#  'johnson': 31270,
#  'robertlee': 49122,
#  'thomas': 57237,
#  'meers': 36115,
#  'marittamullet': 35373,
#  'james': 30686,
#  'prentice': 44978,
#  'kerryroper': 31965,
#  'sally': 49840,
#  'shuler': 51672,
#  'jfarmer': 30999,
#  'steven': 53685,
#  'elliott': 19085,
#  'john': 31250,
#  'nowlan': 39761,
#  'fred': 23024,
#  'boas': 7469,
#  'gregg': 25115,
#  'lenart': 33314,
#  'methanol': 36505,
#  'nominates': 39361,
#  'following': 22436,
#  'requirements': 48242,
#  'themethanol': 56533,
#  'plant': 43976,
#  'july': 31524,
#  'mmbtu': 37196,
#  'per': 43040,
#  'dayegpfc': 15157,
#  'mtbe': 37979,
#  'atmorgan': 4692,
#  'point': 44357,
#  'day': 15146,
#  'hpl': 27439,
#  'february': 21469,
#  'see': 50655,
#  'attached': 4740,
#  'file': 21797,
#  'hplno': 27467,
#  'xls': 63817,
#  'error': 20096,
#  'repairsjay': 48034,
#  'june': 31541,
#  'need': 38637,
#  'couple': 13858,
#  'things': 57029,
#  'changed': 10492,
#  'deal': 15315,
#  'commodity': 12283,
#  'price': 45132,
#  'needs': 38684,
#  'waha': 61609,
#  'hub': 27640,
#  'gdp': 23982,
#  'looks': 34275,
#  'like': 33602,
#  'missing': 37068,
#  'volume': 61349,
#  'baseload': 5720,
#  'allocated': 1897,
#  'priced': 45140,
#  'currently': 14514,
#  'scheduled': 50217,
#  'column': 12043,
#  'based': 5715,
#  'spreadsheet': 53158,
#  'sent': 50866,
#  'conflicting': 12877,
#  'volumes': 61368,
#  'resending': 48290,
#  'pricing': 45190,
#  'think': 57037,
#  'wait': 61620,
#  'changes': 10512,
#  'come': 12115,
#  'across': 580,
#  'please': 44096,
#  'notify': 39648,
#  'made': 34815,
#  'thanks': 55873,
#  'original': 41448,
#  'message': 36424,
#  'vela': 60688,
#  'valeriesent': 60445,
#  'tuesday': 59110,
#  'august': 4903,
#  'smith': 52298,
#  'josephsubject': 31341,
#  'repairsthanks': 48037,
#  'josephsent': 31339,
#  'valeriesubject': 60446,
#  'repairsthe': 48038,
#  'errors': 20103,
#  'also': 2042,
#  'repaired': 48030,
#  'month': 37528,
#  'repairsthank': 48036,
#  'look': 34255,
#  'change': 10487,
#  'repairsvalerie': 48039,
#  'reference': 47577,
#  'note': 39584,
#  'darren': 14990,
#  'houston': 27346,
#  'pipleline': 43810,
#  'mistake': 37084,
#  'ththe': 57382,
#  'proper': 45730,
#  'value': 60524,
#  'mentioned': 36314,
#  'everything': 20481,
#  'fixed': 22076,
#  'let': 33384,
#  'know': 32315,
#  'anything': 3384,
#  'else': 19129,
#  'jay': 30790,
#  'actuals': 678,
#  'october': 40205,
#  'teco': 55465,
#  'tap': 55226,
#  'daily': 14801,
#  'jan': 30710,
#  'feb': 21465,
#  'midcon': 36684,
#  'invoicespat': 29928,
#  'dresner': 17828,
#  'accountant': 370,
#  'texas': 55777,
#  'says': 50117,
#  'show': 51616,
#  'dealsin': 15380,
#  'system': 54955,
#  'pay': 42726,
#  'created': 14091,
#  'deals': 15360,
#  'sitaraand': 51954,
#  'another': 3188,
#  'trader': 58525,
#  'name': 38371,
#  'could': 13779,
#  'talk': 55152,
#  'kntrader': 32357,
#  'regarding': 47668,
#  'situation': 52011,
#  'really': 47198,
#  'got': 24838,
#  'someoneat': 52633,
#  'kn': 32270,
#  'tell': 55546,
#  'prod': 45399,
#  'mo': 37271,
#  'entity': 19760,
#  'total': 58333,
#  'amount': 2352,
#  'services': 50998,
#  'corp': 13593,
#  'pipeline': 43774,
#  'soon': 52701,
#  'possible': 44638,
#  'find': 21919,
#  'production': 45431,
#  'invoices': 29920,
#  'due': 18059,
#  'paid': 42186,
#  'thank': 55867,
#  'tina': 57611,
#  'valadez': 60428,
#  'revised': 48633,
#  'th': 55853,
#  'noms': 39425,
#  'ami': 2289,
#  'chokshi': 10946,
#  'royal': 49390,
#  'b': 5285,
#  'edmondson': 18654,
#  'reliantenergy': 47858,
#  'com': 12050,
#  'amto': 2404,
#  'enroncc': 19617,
#  'egmnom': 18816,
#  'love': 34409,
#  'ya': 63981,
#  'miss': 37057,
#  'channel': 10549,
#  'dispatch': 16977,
#  'fyi': 23552,
#  'gary': 23753,
#  'hanks': 25770,
#  'weir': 62167,
#  'gordon': 24804,
#  'r': 46795,
#  'blake': 7219,
#  'schwarz': 50321,
#  'charlie': 10629,
#  'mcgarity': 35876,
#  'quinn': 46699,
#  'deborahvalenzuela': 15459,
#  'dwight': 18234,
#  'gentry': 24124,
#  'garald': 23714,
#  'ross': 49323,
#  'martinez': 35521,
#  'gregory': 25117,
#  'neese': 38710,
#  'harryzimmer': 25898,
#  'armenta': 4042,
#  'jamesjohnston': 30693,
#  'jimmy': 31074,
#  'logan': 34131,
#  'jimmysteele': 31077,
#  'kelly': 31901,
#  'prespentt': 45062,
#  'kent': 31939,
#  'barnes': 5646,
#  'larry': 32874,
#  'jaquet': 30762,
#  'patphillips': 42658,
#  'phil': 43450,
#  'tibbets': 57440,
#  'richard': 48804,
#  'caster': 9891,
#  'robert': 49114,
#  'shimek': 51429,
#  'young': 64336,
#  'ronnie': 49271,
#  'benson': 6532,
#  'russell': 49582,
#  'cowart': 13935,
#  'ryan': 49651,
#  'coffey': 11890,
#  'scheduling': 50240,
#  'epfs': 19863,
#  'scott': 50374,
#  'brown': 8364,
#  'steve': 53677,
#  'jurecek': 31566,
#  'liles': 33628,
#  'van': 60543,
#  'matre': 35651,
#  'walterfarley': 61692,
#  'audrey': 4887,
#  'pullen': 46086,
#  'chrissonneborne': 11004,
#  'earl': 18372,
#  'tisdale': 57664,
#  'mckay': 35891,
#  'kimberly': 32113,
#  'vaughn': 60627,
#  'lauriallen': 33005,
#  'mike': 36768,
#  'morriscc': 37727,
#  'book': 7632,
#  'panenergy': 42302,
#  'marketing': 35398,
#  'exchange': 20608,
#  'dealsitara': 15382,
#  'pls': 44203,
#  'rate': 46996,
#  'adjusted': 868,
#  'reflect': 47613,
#  'thecontract': 56214,
#  'pipe': 43773,
#  'pgevpoint': 43351,
#  'carthage': 9787,
#  'pgev': 43350,
#  'unify': 59738,
#  'hsc': 27524,
#  'idx': 28090,
#  'contract': 13251,
#  'shell': 51353,
#  'openfirst': 41106,
#  'first': 22013,
#  'serve': 50959,
#  'open': 41103,
#  'badges': 5391,
#  'available': 5063,
#  'try': 59032,
#  'share': 51253,
#  'best': 6682,
#  'wecan': 62072,
#  'one': 40850,
#  'passes': 42555,
#  'invitations': 29899,
#  'tonights': 58131,
#  'mardi': 35320,
#  'gras': 25004,
#  'party': 42526,
#  'tickets': 57463,
#  'saturday': 50050,
#  'beauty': 6021,
#  'n': 38332,
#  'blues': 7393,
#  'concert': 12717,
#  'might': 36742,
#  'good': 24756,
#  'time': 57553,
#  'remind': 47927,
#  'week': 62100,
#  'secretary': 50592,
#  'since': 51882,
#  'holding': 27000,
#  'goodies': 24768,
#  'joking': 31301,
#  'brenda': 8099,
#  'yvettex': 64639,
#  'actual': 660,
#  'flow': 22271,
#  'thru': 57371,
#  'agree': 1360,
#  'nominated': 39356,
#  'totals': 58347,
#  'eileen': 18877,
#  'ponton': 44476,
#  'avila': 5130,
#  'lsp': 34522,
#  'enserch': 19685,
#  'us': 60141,
#  'tu': 59091,
#  'stone': 53808,
#  'utilities': 60287,
#  'melissajones': 36223,
#  'liz': 33919,
#  'bellamy': 6386,
#  'comcc': 12092,
#  'date': 15051,
#  'mcf': 35867,
#  'btu': 8481,
#  'troy': 58965,
#  'benoit': 6527,
#  'december': 15500,
#  'meter': 36470,
#  'april': 3651,
#  'came': 9296,
#  'sitarra': 51979,
#  'papyotti': 42349,
#  'place': 43904,
#  'dealnumber': 15351,
#  'told': 58034,
#  'ask': 4287,
#  'juliehuish': 31514,
#  'detergents': 16265,
#  'inc': 28655,
#  'upsetsthe': 60060,
#  'determined': 16272,
#  'full': 23384,
#  'attained': 4762,
#  'sooner': 52703,
#  'thantheir': 55933,
#  'forecast': 22586,
#  'remains': 47899,
#  'approximately': 3637,
#  'mbd': 35787,
#  'today': 57886,
#  'tomorrow': 58096,
#  'thursday': 57416,
#  'march': 35298,
#  'mbdstarting': 35788,
#  'friday': 23143,
#  'may': 35725,
#  'assistance': 4457,
#  'issue': 30292,
#  'tried': 58871,
#  'extend': 20942,
#  'itblocked': 30378,
#  'saying': 50115,
#  'processing': 45367,
#  'company': 12368,
#  'suspended': 54677,
#  'inactive': 28609,
#  'counterparty': 13824,
#  'extended': 20945,
#  'suggestions': 54343,
#  'olsen': 40769,
#  'na': 38333,
#  'make': 35010,
#  'sure': 54581,
#  'zero': 64756,
#  'dmichael': 17252,
#  'management': 35108,
#  'wondering': 63207,
#  'needed': 38649,
#  'beextended': 6200,
#  'meto': 36530,
#  'meeting': 36118,
#  'thoughtsi': 57296,
#  'sitting': 52007,
#  'bit': 7099,
#  'disappointed': 16827,
#  'pissed': 43831,
#  'pat': 42596,
#  'honestly': 27129,
#  'believe': 6364,
#  'man': 35104,
#  'word': 63250,
#  'onsetting': 41018,
#  'link': 33724,
#  'builder': 8577,
#  'something': 52644,
#  'wrong': 63515,
#  'links': 33738,
#  'forthe': 22820,
#  'last': 32900,
#  'several': 51096,
#  'days': 15178,
#  'work': 63273,
#  'late': 32926,
#  'ofeach': 40317,
#  'setting': 51061,
#  'much': 38011,
#  'going': 24694,
#  'play': 44049,
#  'game': 23671,
#  'mr': 37905,
#  'lloyd': 33983,
#  'took': 58161,
#  'showup': 51640,
#  'coached': 11759,
#  'well': 62189,
#  'done': 17486,
#  'whento': 62430,
#  'entirely': 19749,
#  'predictable': 44915,
#  'always': 2120,
#  'thought': 57289,
#  'said': 49754,
#  'better': 6741,
#  'hung': 27732,
#  'attl': 4805,
#  'htm': 27560,
#  'wc': 61963,
#  'revision': 48646,
#  'effective': 18736,
#  'stingray': 53747,
#  'p': 42110,
#  'holmes': 27038,
#  'cc': 10069,
#  'send': 50826,
#  'formal': 22695,
#  'noticecancelling': 39627,
#  'force': 22562,
#  'majeure': 34980,
#  'later': 32933,
#  'afternoon': 1230,
#  'reveffo': 48575,
#  'order': 41334,
#  'confirmation': 12854,
#  'footlocker': 22519,
#  'comdear': 12106,
#  'ordering': 41343,
#  'number': 39880,
#  'customer': 14572,
#  'ship': 51437,
#  'within': 63004,
#  'hours': 27315,
#  'upon': 60045,
#  'credit': 14113,
#  'card': 9614,
#  'approval': 3615,
#  'detail': 16234,
#  'received': 47302,
#  'shipping': 51457,
#  'meadow': 35965,
#  'treespringtx': 58809,
#  'qty': 46512,
#  'product': 45420,
#  'description': 16108,
#  'nike': 39162,
#  'men': 36284,
#  'air': 1504,
#  'team': 55388,
#  'unite': 59781,
#  'white': 62509,
#  'black': 7181,
#  'subtotal': 54259,
#  'tax': 55291,
#  'discounts': 16874,
#  'credits': 14122,
#  'email': 19156,
#  'notification': 39640,
#  'aware': 5181,
#  'senders': 50829,
#  'automatically': 5005,
#  'notified': 39645,
#  'stop': 53823,
#  'sending': 50831,
#  'internet': 29663,
#  'mail': 34898,
#  'address': 773,
#  'sendfuture': 50830,
#  'communications': 12317,
#  'fpam': 22938,
#  'hotmail': 27288,
#  'mjones': 37140,
#  'txu': 59326,
#  'comreminder': 12642,
#  'used': 60172,
#  'longer': 34229,
#  'bedeactivated': 6088,
#  'contacts': 13159,
#  'switch': 54826,
#  'new': 38888,
#  'subscribed': 54226,
#  'mailing': 34921,
#  'lists': 33846,
#  'makesure': 35030,
#  'update': 59970,
#  'addresses': 782,
#  'andyour': 2982,
#  'shortname': 51577,
#  'e': 18327,
#  'jsmith': 31427,
#  'continue': 13221,
#  'towork': 58442,
#  'even': 20414,
#  'though': 57286,
#  'longname': 34245,
#  'reply': 48085,
#  'generated': 24069,
#  'walter': 61690,
#  'g': 23571,
#  'superior': 54466,
#  'nomstom': 39441,
#  'recently': 47338,
#  'package': 42126,
#  'theaforementioned': 56088,
#  'follows': 22454,
#  'latest': 32948,
#  'chg': 10826,
#  'dwalter': 18224,
#  'dsuperior': 17983,
#  'dtotal': 18019,
#  'di': 16481,
#  'vltx': 61259,
#  'kcs': 31838,
#  'buy': 8879,
#  'selllauri': 50788,
#  'control': 13336,
#  'provide': 45856,
#  'information': 29141,
#  'called': 9232,
#  'bob': 7484,
#  'witherswith': 62988,
#  'agreement': 1367,
#  'reduce': 47526,
#  'thechanges': 56185,
#  'boblauri': 7503,
#  'allen': 1842,
#  'cotten': 13759,
#  'edward': 18686,
#  'terry': 55710,
#  'jill': 31056,
#  'tzivley': 59378,
#  'mary': 35542,
#  'poorman': 44491,
#  'enronsubject': 19669,
#  'sellin': 50781,
#  'light': 33580,
#  'allocation': 1906,
#  'asthough': 4527,
#  'tejas': 55501,
#  'riverside': 48974,
#  'sell': 50775,
#  'portion': 44579,
#  'occurs': 40169,
#  'remainder': 47891,
#  'ofjanuary': 40482,
#  'receipts': 47290,
#  'mm': 37191,
#  'average': 5104,
#  'january': 30748,
#  'bereduced': 6579,
#  'approx': 3632,
#  'large': 32851,
#  'diffencebetween': 16610,
#  'wellhead': 62196,
#  'delivered': 15801,
#  'back': 5321,
#  'attejas': 4765,
#  'info': 29113,
#  'get': 24215,
#  'actualflow': 665,
#  'current': 14507,
#  'would': 63402,
#  'help': 26363,
#  'nail': 38355,
#  'south': 52788,
#  'katy': 31795,
#  'unit': 59774,
#  'allocationno': 1915,
#  'gtc': 25305,
#  'firm': 22001,
#  'create': 14089,
#  'juliedaren': 31510,
#  'julie': 31505,
#  'meyers': 36555,
#  'allocationjm': 1912,
#  'still': 53723,
#  'valid': 60461,
#  'want': 61721,
#  'roll': 49225,
#  'sepand': 50886,
#  'oct': 40189,
#  'mccoy': 35852,
#  'allocationdaren': 1909,
#  'september': 50905,
#  'feedback': 21496,
#  'purchase': 46123,
#  'duke': 18073,
#  'gathering': 23893,
#  'erroring': 20098,
#  'toit': 58015,
#  'expiration': 20844,
#  'however': 27412,
#  'showed': 51622,
#  'pops': 44504,
#  'w': 61564,
#  'oa': 40016,
#  'according': 361,
#  'theallocation': 56096,
#  'statement': 53505,
#  'noticed': 39629,
#  'outthere': 41887,
#  'either': 18901,
#  'sheet': 51331,
#  'ifyou': 28176,
#  'markx': 35462,
#  'handle': 25723,
#  'wise': 62912,
#  'artof': 4173,
#  'expecting': 20767,
#  'big': 6915,
#  'results': 48468,
#  'grasshopper': 25009,
#  'shut': 51676,
#  'spoke': 53098,
#  'shortly': 51576,
#  'say': 50112,
#  'letter': 33398,
#  'long': 34226,
#  'repair': 48029,
#  'remedy': 47916,
#  'ever': 20442,
#  'take': 55108,
#  'remain': 47890,
#  'meets': 36147,
#  'specs': 52985,
#  'suggestion': 54342,
#  'morris': 37725,
#  'left': 33242,
#  'heard': 26217,
#  'therefore': 56713,
#  'anyone': 3362,
#  'give': 24437,
#  'advise': 1024,
#  'contents': 13194,
#  'advance': 978,
#  'north': 39518,
#  'america': 2243,
#  'cheryl': 10799,
#  'dudley': 18057,
#  'shawna': 51310,
#  'flynn': 22364,
#  'enronxgate': 19678,
#  'ectsubject': 18583,
#  'tri': 58838,
#  'c': 9063,
#  'resources': 48359,
#  'gov': 24868,
#  'daniel': 14904,
#  'producer': 45411,
#  'high': 26691,
#  'hydrocarbon': 27840,
#  'dew': 16388,
#  'questions': 46636,
#  'call': 9221,
#  'thanksgary': 55885,
#  'deletion': 15764,
#  'enrononline': 19652,
#  'user': 60188,
#  'idpassword': 28086,
#  'deletionit': 15765,
#  'noted': 39595,
#  'many': 35261,
#  'users': 60200,
#  'passwords': 42578,
#  'match': 35610,
#  'similarto': 51837,
#  'id': 28030,
#  'internal': 29642,
#  'applications': 3555,
#  'stack': 53347,
#  'manager': 35132,
#  'eol': 19831,
#  'reports': 48129,
#  'significant': 51771,
#  'security': 50636,
#  'concern': 12709,
#  'sweep': 54770,
#  'ofid': 40468,
#  'end': 19428,
#  'swhich': 54789,
#  'similar': 51832,
#  'changing': 10545,
#  'passwordpasswords': 42577,
#  'password': 42570,
#  'logged': 34138,
#  'go': 24640,
#  'toolbar': 58165,
#  'select': 50742,
#  'request': 48201,
#  'enter': 19701,
#  'twice': 59253,
#  'passsword': 42568,
#  'application': 3551,
#  'login': 34145,
#  'options': 41253,
#  'toenter': 57941,
#  'changefunctionality': 10498,
#  'appear': 3508,
#  'onyour': 41054,
#  'menu': 36320,
#  'running': 49558,
#  'standalone': 53416,
#  'machine': 34778,
#  'tologout': 58050,
#  'windows': 62820,
#  'level': 33422,
#  'receive': 47299,
#  'updatedversion': 59982,
#  'desk': 16154,
#  'london': 34199,
#  'preserving': 45048,
#  'appropriate': 3609,
#  'dave': 15093,
#  'x': 63648,
#  'productsplease': 45491,
#  'read': 47147,
#  'schedulers': 50230,
#  'understand': 59667,
#  'newproduct': 38941,
#  'physical': 43579,
#  'delivery': 15810,
#  'pointswithin': 44377,
#  'trades': 58531,
#  'f': 21078,
#  'herod': 26533,
#  'eric': 20038,
#  'bass': 5768,
#  'baumbach': 5834,
#  'neal': 38584,
#  'winfree': 62839,
#  'michaelwalters': 36644,
#  'bryan': 8424,
#  'hull': 27686,
#  'jeff': 30883,
#  'crook': 14235,
#  'amichokshi': 2294,
#  'venturatos': 60730,
#  'productswe': 45497,
#  'rolling': 49232,
#  'starting': 53478,
#  'bidweek': 6904,
#  'weekdays': 62103,
#  'weekenddelivery': 62106,
#  'bridge': 8172,
#  'cannot': 9460,
#  'type': 59349,
#  'oflogic': 40488,
#  'input': 29387,
#  'manually': 35245,
#  'dale': 14849,
#  'neuner': 38861,
#  'forster': 22803,
#  'sheri': 51377,
#  'jenniferdeboisblanc': 30925,
#  'denny': 15938,
#  'jason': 30772,
#  'althaus': 2082,
#  'jasonalthaus': 30773,
#  'melba': 36205,
#  'lozano': 34456,
#  'use': 60168,
#  'nat': 38446,
#  'commencing': 12210,
#  'traded': 58516,
#  'texasdesk': 55784,
#  'identified': 28052,
#  'phy': 43571,
#  'exxon': 21024,
#  'wkd': 63110,
#  'juno': 31558,
#  'usd': 60162,
#  'mmthis': 37247,
#  'different': 16617,
#  'usual': 60256,
#  'products': 45477,
#  'inthat': 29728,
#  'anindicator': 3078,
#  'designates': 16135,
#  'moves': 37855,
#  'daythat': 15192,
#  'monday': 37417,
#  'wednesday': 62087,
#  'risk': 48931,
#  'personnel': 43228,
#  'bediligent': 6099,
#  'identify': 28057,
#  'basedon': 5717,
#  'ensure': 19689,
#  'areentered': 3866,
#  'correctly': 13652,
#  'presumably': 45084,
#  'strips': 54044,
#  'corresponding': 13667,
#  'daysand': 15179,
#  'ending': 19437,
#  'potential': 44696,
#  'impact': 28434,
#  'thesetransactions': 56843,
#  'asked': 4288,
#  'appropriatesystems': 3613,
#  'examine': 20551,
#  'considerbuilding': 13033,
#  'capability': 9522,
#  'theinterim': 56403,
#  'anticipate': 3251,
#  'trading': 58542,
#  'low': 34431,
#  'higher': 26706,
#  'prioritization': 45257,
#  'thebridging': 56157,
#  'event': 20432,
#  'increase': 28799,
#  'fw': 23524,
#  'megan': 36160,
#  'pics': 43638,
#  'clay': 11443,
#  'carbaugh': 9595,
#  'mailto': 34943,
#  'ectisp': 18574,
#  'net': 38796,
#  'glover': 24576,
#  'rustysubject': 49598,
#  'picssorry': 43642,
#  'fill': 21830,
#  'elizabeth': 19064,
#  'shewas': 51405,
#  'born': 7694,
#  'sunday': 54414,
#  'rd': 47108,
#  'weighed': 62149,
#  'lbs': 33077,
#  'oz': 42098,
#  'inches': 28686,
#  'fine': 21933,
#  'amy': 2421,
#  'thesepictures': 56827,
#  'missed': 37060,
#  'round': 49350,
#  'rustyto': 49599,
#  'pmsubject': 44288,
#  'picscongratulations': 43640,
#  'everyone': 20468,
#  'ok': 40687,
#  'somemore': 52627,
#  'rusty': 49596,
#  'wade': 61584,
#  'dinkins': 16721,
#  'victor': 60974,
#  'tonya': 58152,
#  'tishthemcmeans': 57668,
#  'uswest': 60265,
#  'teenagalva': 55478,
#  'aol': 3410,
#  'stacy': 53351,
#  'steen': 53605,
#  'lowes': 34442,
#  'shirleykubin': 51480,
#  'rebecca': 47241,
#  'lux': 34676,
#  'family': 21212,
#  'kyle': 32619,
#  'krysta': 32504,
#  'patterson': 42682,
#  'katherine': 31769,
#  'agee': 1283,
#  'doc': 17301,
#  'durbin': 18157,
#  'debbie': 15443,
#  'holmelin': 27037,
#  'dan': 14878,
#  'cynthia': 14724,
#  'aunt': 4924,
#  'brian': 8146,
#  'bill': 6964,
#  'audraamy': 4886,
#  'catesubject': 9954,
#  'picshere': 43641,
#  'baby': 5301,
#  'meganl': 36166,
#  'jpg': 31383,
#  'flowhpl': 22293,
#  'ls': 34506,
#  'availabilitiesthis': 5058,
#  'avails': 5078,
#  'devon': 16373,
#  'sept': 50900,
#  'suremore': 54586,
#  'follow': 22432,
#  'beverly': 6781,
#  'beaty': 5997,
#  'capital': 9544,
#  'trade': 58512,
#  'cantrell': 9503,
#  'availabilitiesthe': 5057,
#  'reflects': 47620,
#  'availabilities': 5044,
#  'copy': 13498,
#  'final': 21863,
#  'numbers': 39895,
#  'anychanges': 3330,
#  'enronavailso': 19613,
#  'neededvance': 38669,
#  'entered': 19703,
#  'samson': 49899,
#  'lone': 34217,
#  'starlimited': 53461,
#  'yet': 64121,
#  'awaitingadditional': 5168,
#  'hesco': 26558,
#  'bobvance': 7514,
#  'taylor': 55306,
#  'lisa': 33779,
#  'hesse': 26569,
#  'trisha': 58916,
#  'hughes': 27676,
#  'heidiwithers': 26307,
#  'hillary': 26778,
#  'mack': 34789,
#  'susan': 54656,
#  'donald': 17472,
#  'reinhardt': 47775,
#  'melissa': 36219,
#  'graves': 25034,
#  'neededbob': 38651,
#  'line': 33683,
#  'andentered': 2644,
#  'periodhesco': 43121,
#  'oil': 40648,
#  'co': 11753,
#  'less': 33364,
#  'star': 53450,
#  ...}

# %%
len(num_words.vocabulary_)
# Out:
# 65032

# %% [markdown]
# ## **Step 3: Find the frequency of occurance of words**

# %%
freq_word = num_words.transform(X)
print(freq_word)
# Out:
#   (0, 300)	1
#   (0, 758)	1
#   (0, 1421)	2
#   (0, 4692)	1
#   (0, 5709)	1
#   (0, 7469)	1
#   (0, 8747)	1
#   (0, 13643)	1
#   (0, 14940)	3
#   (0, 15103)	2
#   (0, 15146)	1
#   (0, 15157)	1
#   (0, 16585)	1
#   (0, 18514)	4
#   (0, 18567)	13
#   (0, 18570)	2
#   (0, 19085)	1
#   (0, 19605)	22
#   (0, 21266)	2
#   (0, 22197)	1
#   (0, 22436)	2
#   (0, 22859)	1
#   (0, 23024)	1
#   (0, 23766)	5
#   (0, 24775)	1
#   :	:
#   (5171, 38888)	1
#   (5171, 39011)	1
#   (5171, 39810)	1
#   (5171, 40922)	2
#   (5171, 42877)	1
#   (5171, 43356)	1
#   (5171, 43436)	1
#   (5171, 45007)	1
#   (5171, 45477)	1
#   (5171, 47002)	1
#   (5171, 47299)	1
#   (5171, 49647)	2
#   (5171, 51457)	1
#   (5171, 51537)	1
#   (5171, 52605)	1
#   (5171, 52963)	1
#   (5171, 53861)	1
#   (5171, 54196)	1
#   (5171, 60518)	1
#   (5171, 61223)	1
#   (5171, 62918)	1
#   (5171, 63599)	2
#   (5171, 63805)	1
#   (5171, 63940)	1
#   (5171, 64887)	1

# %% [markdown]
# We are finding out in each email which word is more important or the most significant

# %%
tfidf_transformer = TfidfTransformer().fit(freq_word)
email_tfidf = tfidf_transformer.transform(freq_word)
print(email_tfidf)
# Out:
#   (0, 62241)	0.05040598209212112
#   (0, 57450)	0.11001166595911799
#   (0, 57237)	0.04938835592828937
#   (0, 56533)	0.06403050328855155
#   (0, 54806)	0.047237432598002047
#   (0, 54196)	0.02859357854565269
#   (0, 53685)	0.0634857154233257
#   (0, 53467)	0.04353469025902173
#   (0, 51953)	0.034218914588648064
#   (0, 51672)	0.0724875611552405
#   (0, 51610)	0.08442788660149295
#   (0, 49840)	0.05496656487547695
#   (0, 49122)	0.07569454293066054
#   (0, 48242)	0.10163492877571842
#   (0, 46218)	0.0416995247377028
#   (0, 44978)	0.0724875611552405
#   (0, 44357)	0.04067917245505417
#   (0, 44290)	0.05431345868024831
#   (0, 44242)	0.029859732075054067
#   (0, 43976)	0.07807737690118617
#   (0, 43040)	0.07051187125668165
#   (0, 42701)	0.07569454293066054
#   (0, 42328)	0.10711883539893585
#   (0, 39761)	0.06817960377616929
#   (0, 39365)	0.10789946264197758
#   :	:
#   (5171, 40922)	0.16421666042184882
#   (5171, 39810)	0.17701574548832685
#   (5171, 39011)	0.17701574548832685
#   (5171, 38888)	0.059726196281358813
#   (5171, 37680)	0.16891310211331834
#   (5171, 33753)	0.14294878002221525
#   (5171, 33437)	0.1396104417896613
#   (5171, 30610)	0.061995425410043825
#   (5171, 30398)	0.10485668785917773
#   (5171, 27631)	0.1299835319006527
#   (5171, 27587)	0.17701574548832685
#   (5171, 27272)	0.10972512860679935
#   (5171, 24089)	0.11392758318828725
#   (5171, 18939)	0.17701574548832685
#   (5171, 17934)	0.21136742506001072
#   (5171, 16912)	0.13546106447021364
#   (5171, 16874)	0.13202688155795958
#   (5171, 16872)	0.11570507216053924
#   (5171, 15291)	0.17701574548832685
#   (5171, 15146)	0.06263803953968043
#   (5171, 10697)	0.109047654324563
#   (5171, 9063)	0.07409238362009797
#   (5171, 8879)	0.08982542637159735
#   (5171, 7135)	0.22157290582440406
#   (5171, 2180)	0.1300268560164071

# %%
X_train, X_test, Y_train, Y_test = train_test_split(email_tfidf, Y, test_size=0.20, random_state=50)

# %% [markdown]
# ## **Step 4: Trying out different Classifiers**

# %% [markdown]
# ## **Naive Bayes**

# %% [markdown]
# **Multinomial Naive Bayes**

# %%
MultiNB = MultinomialNB()
MultiNB.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
Y_predict = MultiNB.predict(X_test)

print("The accuracy is: ",accuracy_score(Y_test, Y_predict)*100,"%")
# Out:
# The accuracy is:  89.17874396135265 %

# %%
print(confusion_matrix(Y_test, Y_predict))
# Out:
# [[743   0]
#  [112 180]]

# %% [markdown]
# **Gaussian Naive Bayes**

# %%
GausNB = GaussianNB()
GausNB.fit(X_train.toarray(),Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
Y_predict = GausNB.predict(X_test.toarray())

print("The accuracy is: ",accuracy_score(Y_test, Y_predict)*100,"%")
# Out:
# The accuracy is:  96.03864734299516 %

# %%
print(confusion_matrix(Y_test, Y_predict))
# Out:
# [[730  13]
#  [ 28 264]]

# %% [markdown]
# **Bernoulli Naive Bayes**

# %%
BernNB = BernoulliNB(binarize = 0.05)
BernNB.fit(X_train,Y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.05, class_prior=None, fit_prior=True)

# %%
Y_predict = BernNB.predict(X_test)

print("The accuracy is: ",accuracy_score(Y_test, Y_predict)*100,"%")
# Out:
# The accuracy is:  86.76328502415458 %

# %%
print(confusion_matrix(Y_test, Y_predict))
# Out:
# [[734   9]
#  [128 164]]

# %% [markdown]
# ## **Support Vector Machine (SVM)**

# %% [markdown]
# **Linear Support Vector Machine**

# %%
SVML = LinearSVC()
SVML.fit(X_train,Y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
Y_predict = SVML.predict(X_test)

print("The accuracy is: ",accuracy_score(Y_test, Y_predict)*100,"%")
# Out:
# The accuracy is:  98.16425120772946 %

# %%
print(confusion_matrix(Y_test, Y_predict))
# Out:
# [[728  15]
#  [  4 288]]

# %% [markdown]
# **Quadratic Support Vector Machine**

# %%
SVMQ = SVC(kernel='poly', degree=2, gamma='scale')
SVMQ.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=2, gamma='scale', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
Y_predict = SVMQ.predict(X_test)

print("The accuracy is: ",accuracy_score(Y_test, Y_predict)*100,"%")
# Out:
# The accuracy is:  99.03381642512076 %

# %%
print(confusion_matrix(Y_test, Y_predict))
# Out:
# [[740   3]
#  [  7 285]]
